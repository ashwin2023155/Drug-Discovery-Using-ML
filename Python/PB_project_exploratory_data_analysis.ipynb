# %% [markdown]
# <a href="https://colab.research.google.com/github/GolDRoger69/Drug-Discovery-using-ML/blob/main/Python/PB_project_exploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Drug Discovery -- Exploratory Data Analysis**
#
#
#
# ---

# %% [markdown]
# ## **Install conda and rdkit**

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2025-05-03 12:16:12--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.1’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   114MB/s    in 0.7s
#
# 2025-05-03 12:16:12 (114 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.1’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::libxcb==1.17.0=h9b100fa_0
#   - defaults/linux-64::expat==2.7.1=h6a678d5_0
#   - defaults/linux-64::certifi==2022.12.7=py37h06a4308_0
#   - defaults/linux-64::xz==5.6.4=h5eee18b_1
#   - defaults/noarch::pycparser==2.21=pyhd3eb1b0_0
#   - defaults/linux-64::mkl_random==1.2.2=py37h51133e4_0
#   - defaults/linux-64::libstdcxx-ng==11.2.0=h1234567_1
#   - defaults/linux-64::pillow==9.4.0=py37h6a678d5_0
#   - defaults/linux-64::lcms2==2.16=hb9589c4_0
#   - defaults/linux-64::py-boost==1.73.0=py37h51133e4_12
#   - defaults/linux-64::libboost==1.73.0=h28710b8_12
#   - defaults/linux-64::glib==2.63.1=h5a9c865_0
#   - defaults/linux-64::cryptography==39.0.1=py37h9ce1e76_0
#   - defaults/noarch::charset-normalizer==2.0.4=pyhd3eb1b0_0
#   - defaults/linux-64::zipp==3.11.0=py37h06a4308_0
#   - defaults/linux-64::urllib3==1.26.14=py37h06a4308_0
#   - defaults/linux-64::importlib-metadata==4.11.3=py37h06a4308_0
#   - defaults/linux-64::requests==2.28.1=py37h06a4308_0
#   - defaults/linux-64::ruamel.yaml.clib==0.2.6=py37h5eee18b_1
#   - defaults/linux-64::lz4-c==1.9.4=h6a678d5_1
#   - defaults/linux-64::zstandard==0.15.2=py37h27cfd23_0
#   - defaults/linux-64::six==1.14.0=py37_0
#   - defaults/linux-64::ruamel_yaml==0.15.87=py37h7b6447c_0
#   - defaults/linux-64::freetype==2.13.3=h4a9f257_0
#   - defaults/linux-64::libdeflate==1.22=h5eee18b_0
#   - defaults/linux-64::libedit==3.1.20230828=h5eee18b_0
#   - defaults/linux-64::wheel==0.38.4=py37h06a4308_0
#   - defaults/linux-64::libwebp-base==1.2.4=h5eee18b_1
#   - defaults/linux-64::pixman==0.40.0=h7f8727e_1
#   - defaults/linux-64::toolz==0.12.0=py37h06a4308_0
#   - defaults/linux-64::pluggy==1.0.0=py37h06a4308_1
#   - defaults/linux-64::mkl_fft==1.3.1=py37hd3c417c_0
#   - defaults/linux-64::conda==23.1.0=py37h06a4308_0
#   - defaults/linux-64::zlib==1.2.13=h5eee18b_1
#   - defaults/linux-64::numpy-base==1.21.5=py37ha15fc14_3
#   - defaults/linux-64::xorg-libxdmcp==1.1.5=h9b100fa_0
#   - defaults/linux-64::python==3.7.6=h0371630_2
#   - defaults/linux-64::libuuid==1.41.5=h5eee18b_0
#   - defaults/linux-64::pycosat==0.6.4=py37h5eee18b_0
#   - defaults/linux-64::numexpr==2.8.4=py37he184ba9_0
#   - defaults/linux-64::chardet==3.0.4=py37_1003
#   - defaults/linux-64::libpng==1.6.39=h5eee18b_0
#   - defaults/noarch::python-dateutil==2.8.2=pyhd3eb1b0_0
#   - defaults/linux-64::packaging==22.0=py37h06a4308_0
#   - defaults/linux-64::libffi==3.2.1=hf484d3e_1007
#   - defaults/linux-64::pip==22.3.1=py37h06a4308_0
#   - defaults/linux-64::bzip2==1.0.8=h5eee18b_6
#   - defaults/linux-64::tk==8.6.14=h39e8969_0
#   - defaults/linux-64::sqlite==3.33.0=h62c20be_0
#   - defaults/linux-64::xorg-libxau==1.0.12=h9b100fa_0
#   - defaults/linux-64::pyopenssl==23.0.0=py37h06a4308_0
#   - defaults/linux-64::pytz==2022.7=py37h06a4308_0
#   - defaults/linux-64::pysocks==1.7.1=py37_1
#   - defaults/linux-64::cairo==1.14.12=h8948797_3
#   - rdkit/linux-64::rdkit==2020.09.1.0=py37hd50e099_1
#   - defaults/linux-64::cffi==1.15.0=py37h7f8727e_0
#   - defaults/linux-64::libgcc-ng==11.2.0=h1234567_1
#   - defaults/linux-64::conda-package-streaming==0.7.0=py37h06a4308_0
#   - defaults/linux-64::conda-package-handling==2.0.2=py37h06a4308_0
#   - defaults/linux-64::libxml2==2.10.4=hcbfbd50_0
#   - defaults/linux-64::ncurses==6.4=h6a678d5_0
#   - defaults/linux-64::lerc==4.0.0=h6a678d5_0
#   - defaults/noarch::flit-core==3.6.0=pyhd3eb1b0_0
#   - defaults/linux-64::asn1crypto==1.3.0=py37_0
#   - defaults/linux-64::ruamel.yaml==0.17.21=py37h5eee18b_0
#   - defaults/linux-64::tqdm==4.64.1=py37h06a4308_0
#   - defaults/linux-64::bottleneck==1.3.5=py37h7deecbd_0
#   - defaults/linux-64::zstd==1.5.6=hc292b87_0
#   - defaults/linux-64::pthread-stubs==0.3=h0ce48e5_1
#   - defaults/noarch::importlib_metadata==4.11.3=hd3eb1b0_0
#   - defaults/linux-64::icu==58.2=he6710b0_3
#   - defaults/linux-64::openssl==1.1.1w=h7f8727e_0
#   - defaults/linux-64::idna==3.4=py37h06a4308_0
#   - defaults/linux-64::numpy==1.21.5=py37h6c91a56_3
#   - defaults/linux-64::jpeg==9e=h5eee18b_3
#   - defaults/linux-64::libtiff==4.5.1=hffd6297_1
#   - defaults/linux-64::pcre==8.45=h295c915_0
#   - defaults/linux-64::mkl-service==2.4.0=py37h7f8727e_0
#   - defaults/linux-64::typing_extensions==4.4.0=py37h06a4308_0
#   - defaults/linux-64::libwebp==1.2.4=h11a3e52_1
#   - defaults/linux-64::readline==7.0=h7b6447c_5
#   - defaults/linux-64::pandas==1.3.5=py37h8c16a72_0
#   - defaults/linux-64::fontconfig==2.14.1=h4c34cd2_2
#   - defaults/linux-64::brotlipy==0.7.0=py37h27cfd23_1003
#   - defaults/linux-64::setuptools==65.6.3=py37h06a4308_0
#   - defaults/linux-64::giflib==5.2.2=h5eee18b_0
#   - defaults/linux-64::yaml==0.1.7=had09818_2
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following packages will be DOWNGRADED:
#
#   ca-certificates                      2025.2.25-h06a4308_0 --> 2020.1.1-0
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2025.2.25-h06a4308_0
#
#
#
# Downloading and Extracting Packages
#
# done
# done
# done

# %%
import pandas as pd

# %%
# !pip install rdkit
# !pip install boost
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 30.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from rdkit) (1.21.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/site-packages (from rdkit) (9.5.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.3.2
# Requirement already satisfied: boost in /usr/local/lib/python3.7/site-packages (0.1)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/site-packages (from boost) (2.0.40)
# Requirement already satisfied: Mastodon.py in /usr/local/lib/python3.7/site-packages (from boost) (2.0.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/site-packages (from Mastodon.py->boost) (2.8.2)
# Requirement already satisfied: requests>=2.4.2 in /usr/local/lib/python3.7/site-packages (from Mastodon.py->boost) (2.28.1)
# Requirement already satisfied: decorator>=4.0.0 in /usr/local/lib/python3.7/site-packages (from Mastodon.py->boost) (5.1.1)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.7/site-packages (from Mastodon.py->boost) (0.4.27)
# Requirement already satisfied: blurhash>=1.1.4 in /usr/local/lib/python3.7/site-packages (from Mastodon.py->boost) (1.1.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.7/site-packages (from sqlalchemy->boost) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.7/site-packages (from sqlalchemy->boost) (4.7.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/site-packages (from sqlalchemy->boost) (4.11.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.4.2->Mastodon.py->boost) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.4.2->Mastodon.py->boost) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/site-packages (from requests>=2.4.2->Mastodon.py->boost) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.4.2->Mastodon.py->boost) (1.26.14)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata->sqlalchemy->boost) (3.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil->Mastodon.py->boost) (1.14.0)

# %%
df = pd.read_csv('bioactivity_preprocessed_data.csv')
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1299                NaN                                                NaN
# 1300                NaN                                                NaN
# 1301                NaN                                                NaN
# 1302                NaN                                                NaN
# 1303                NaN                                                NaN
#
#       standard_value bioactivity_class bioactivity_class.1
# 0           100000.0          inactive            inactive
# 1            12310.0          inactive            inactive
# 2           100000.0          inactive            inactive
# 3            50970.0          inactive            inactive
# 4           100000.0          inactive            inactive
# ...              ...               ...                 ...
# 1299             NaN      intermediate        intermediate
# 1300             NaN            active              active
# 1301             NaN      intermediate        intermediate
# 1302             NaN            active              active
# 1303             NaN          inactive            inactive
#
# [1304 rows x 5 columns]

# %%
df_no_smiles = df.drop(columns='canonical_smiles')

# %%
smiles = []

for i in df.canonical_smiles.tolist():
  cpd = str(i).split('.')
  cpd_longest = max(cpd, key = len)
  smiles.append(cpd_longest)

smiles = pd.Series(smiles, name = 'canonical_smiles')

# %%
df_clean_smiles = pd.concat([df_no_smiles,smiles], axis=1)
df_clean_smiles
# Out:
#      molecule_chembl_id  standard_value bioactivity_class bioactivity_class.1  \
# 0         CHEMBL1401841        100000.0          inactive            inactive
# 1         CHEMBL1608853         12310.0          inactive            inactive
# 2         CHEMBL1429799        100000.0          inactive            inactive
# 3          CHEMBL246446         50970.0          inactive            inactive
# 4         CHEMBL1383455        100000.0          inactive            inactive
# ...                 ...             ...               ...                 ...
# 1299                NaN             NaN      intermediate        intermediate
# 1300                NaN             NaN            active              active
# 1301                NaN             NaN      intermediate        intermediate
# 1302                NaN             NaN            active              active
# 1303                NaN             NaN          inactive            inactive
#
#                                        canonical_smiles
# 0                            COc1ccc2nc3cccc(OC)c3nc2c1
# 1              O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2     O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3              O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4     CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                                                 ...
# 1299                                                nan
# 1300                                                nan
# 1301                                                nan
# 1302                                                nan
# 1303                                                nan
#
# [1304 rows x 5 columns]

# %% [markdown]
# ## **Calculate Lipinski descriptors**

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %% [markdown]
# ### **Calculate descriptors**

# %%
df_no_smiles = df.drop(columns='canonical_smiles')
smiles = []

for i in df['canonical_smiles'].tolist():
    if pd.isna(i):  # Skip NaN values
        smiles.append('')
    else:
        cpd = str(i).split('.')
        cpd_longest = max(cpd, key=len)
        smiles.append(cpd_longest)

smiles = pd.Series(smiles, name='canonical_smiles')

df_clean_smiles = pd.concat([df_no_smiles, smiles], axis=1)

df_lipinski = lipinski(df_clean_smiles['canonical_smiles'])

# %%
def lipinski(smiles, verbose=False):
    moldata = []
    for elem in smiles:
        if elem is not None and elem != 'nan':  # Skip NaN values
            mol = Chem.MolFromSmiles(elem)
            if mol:  # Only process valid molecules
                moldata.append(mol)
            else:
                moldata.append(None)
        else:
            moldata.append(None)

    baseData = []
    for mol in moldata:
        if mol is not None:  # Skip None values (invalid SMILES)
            desc_MolWt = Descriptors.MolWt(mol)
            desc_MolLogP = Descriptors.MolLogP(mol)
            desc_NumHDonors = Lipinski.NumHDonors(mol)
            desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)

            row = [desc_MolWt, desc_MolLogP, desc_NumHDonors, desc_NumHAcceptors]
            baseData.append(row)
        else:
            # Handle missing descriptors for invalid SMILES (NaN)
            baseData.append([np.nan, np.nan, np.nan, np.nan])

    columnNames = ["MW", "LogP", "NumHDonors", "NumHAcceptors"]
    descriptors = pd.DataFrame(data=baseData, columns=columnNames)

    return descriptors

# %%
df_lipinski = lipinski(df_clean_smiles.canonical_smiles)
df_lipinski
# Out:
#            MW     LogP  NumHDonors  NumHAcceptors
# 0     240.262  2.80020           0              4
# 1     268.224  2.44040           1              4
# 2     407.426  1.38560           1              5
# 3     306.277  3.84800           1              5
# 4     372.772  2.36698           0              8
# ...       ...      ...         ...            ...
# 1299    0.000  0.00000           0              0
# 1300    0.000  0.00000           0              0
# 1301    0.000  0.00000           0              0
# 1302    0.000  0.00000           0              0
# 1303    0.000  0.00000           0              0
#
# [1304 rows x 4 columns]

# %% [markdown]
# ### **Combine DataFrames**

# %%
df_lipinski
# Out:
#            MW     LogP  NumHDonors  NumHAcceptors
# 0     240.262  2.80020           0              4
# 1     268.224  2.44040           1              4
# 2     407.426  1.38560           1              5
# 3     306.277  3.84800           1              5
# 4     372.772  2.36698           0              8
# ...       ...      ...         ...            ...
# 1299    0.000  0.00000           0              0
# 1300    0.000  0.00000           0              0
# 1301    0.000  0.00000           0              0
# 1302    0.000  0.00000           0              0
# 1303    0.000  0.00000           0              0
#
# [1304 rows x 4 columns]

# %%
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1299                NaN                                                NaN
# 1300                NaN                                                NaN
# 1301                NaN                                                NaN
# 1302                NaN                                                NaN
# 1303                NaN                                                NaN
#
#       standard_value bioactivity_class bioactivity_class.1
# 0           100000.0          inactive            inactive
# 1            12310.0          inactive            inactive
# 2           100000.0          inactive            inactive
# 3            50970.0          inactive            inactive
# 4           100000.0          inactive            inactive
# ...              ...               ...                 ...
# 1299             NaN      intermediate        intermediate
# 1300             NaN            active              active
# 1301             NaN      intermediate        intermediate
# 1302             NaN            active              active
# 1303             NaN          inactive            inactive
#
# [1304 rows x 5 columns]

# %%
df_combined = pd.concat([df,df_lipinski], axis=1)

# %%
df_combined
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1299                NaN                                                NaN
# 1300                NaN                                                NaN
# 1301                NaN                                                NaN
# 1302                NaN                                                NaN
# 1303                NaN                                                NaN
#
#       standard_value bioactivity_class bioactivity_class.1       MW     LogP  \
# 0           100000.0          inactive            inactive  240.262  2.80020
# 1            12310.0          inactive            inactive  268.224  2.44040
# 2           100000.0          inactive            inactive  407.426  1.38560
# 3            50970.0          inactive            inactive  306.277  3.84800
# 4           100000.0          inactive            inactive  372.772  2.36698
# ...              ...               ...                 ...      ...      ...
# 1299             NaN      intermediate        intermediate    0.000  0.00000
# 1300             NaN            active              active    0.000  0.00000
# 1301             NaN      intermediate        intermediate    0.000  0.00000
# 1302             NaN            active              active    0.000  0.00000
# 1303             NaN          inactive            inactive    0.000  0.00000
#
#       NumHDonors  NumHAcceptors
# 0              0              4
# 1              1              4
# 2              1              5
# 3              1              5
# 4              0              8
# ...          ...            ...
# 1299           0              0
# 1300           0              0
# 1301           0              0
# 1302           0              0
# 1303           0              0
#
# [1304 rows x 9 columns]

# %%
df_combined = df_combined.dropna()
df_combined
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1209      CHEMBL5205657  COc1ccc(C(=O)CN2C/C(=C/c3ccc([N+](=O)[O-])cc3)...
# 1210       CHEMBL379110  COc1cc(O)c(C(=O)[C@@H]2[C@H](CC=C(C)C)C(C)=CC[...
# 1211      CHEMBL1187898  CCN1/C(=C/C=C/c2oc3ccc4ccccc4c3[n+]2CC)Oc2ccc3...
# 1212      CHEMBL1458891    Cc1ccc(C2=NC(=O)/C(=C/c3cc(O)c(O)c(Br)c3)S2)cc1
# 1213         CHEMBL1324       Cc1ccc(C(=O)c2cc(O)c(O)c([N+](=O)[O-])c2)cc1
#
#       standard_value bioactivity_class bioactivity_class.1       MW     LogP  \
# 0           100000.0          inactive            inactive  240.262  2.80020
# 1            12310.0          inactive            inactive  268.224  2.44040
# 2           100000.0          inactive            inactive  407.426  1.38560
# 3            50970.0          inactive            inactive  306.277  3.84800
# 4           100000.0          inactive            inactive  372.772  2.36698
# ...              ...               ...                 ...      ...      ...
# 1209         16230.0            active              active  513.506  4.74620
# 1210         57280.0            active              active  406.522  6.01160
# 1211         27000.0            active              active  433.531  6.82010
# 1212          2940.0      intermediate        intermediate  390.258  4.22982
# 1213           640.0      intermediate        intermediate  273.244  2.54542
#
#       NumHDonors  NumHAcceptors
# 0              0              4
# 1              1              4
# 2              1              5
# 3              1              5
# 4              0              8
# ...          ...            ...
# 1209           0              8
# 1210           2              4
# 1211           0              3
# 1212           2              4
# 1213           2              5
#
# [1214 rows x 9 columns]

# %% [markdown]
# ### **Convert IC50 to pIC50**

# %%
import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', axis=1)

    return x

# %%
df_combined.standard_value.describe()
# Out:
# count      1214.00000
# mean      47043.73229
# std       34753.18254
# min           6.00000
# 25%       20000.00000
# 50%       40485.00000
# 75%       69380.00000
# max      432000.00000
# Name: standard_value, dtype: float64

# %%
-np.log10( (10**-9)* 100000000 )
# Out:
# np.float64(1.0)

# %%
-np.log10( (10**-9)* 100000000 )
# Out:
# np.float64(1.0)

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', axis = 1)

    return x

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
# <ipython-input-134-112fb8a2af6b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   input['standard_value_norm'] = norm
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1209      CHEMBL5205657  COc1ccc(C(=O)CN2C/C(=C/c3ccc([N+](=O)[O-])cc3)...
# 1210       CHEMBL379110  COc1cc(O)c(C(=O)[C@@H]2[C@H](CC=C(C)C)C(C)=CC[...
# 1211      CHEMBL1187898  CCN1/C(=C/C=C/c2oc3ccc4ccccc4c3[n+]2CC)Oc2ccc3...
# 1212      CHEMBL1458891    Cc1ccc(C2=NC(=O)/C(=C/c3cc(O)c(O)c(Br)c3)S2)cc1
# 1213         CHEMBL1324       Cc1ccc(C(=O)c2cc(O)c(O)c([N+](=O)[O-])c2)cc1
#
#      bioactivity_class bioactivity_class.1       MW     LogP  NumHDonors  \
# 0             inactive            inactive  240.262  2.80020           0
# 1             inactive            inactive  268.224  2.44040           1
# 2             inactive            inactive  407.426  1.38560           1
# 3             inactive            inactive  306.277  3.84800           1
# 4             inactive            inactive  372.772  2.36698           0
# ...                ...                 ...      ...      ...         ...
# 1209            active              active  513.506  4.74620           0
# 1210            active              active  406.522  6.01160           2
# 1211            active              active  433.531  6.82010           0
# 1212      intermediate        intermediate  390.258  4.22982           2
# 1213      intermediate        intermediate  273.244  2.54542           2
#
#       NumHAcceptors  standard_value_norm
# 0                 4             100000.0
# 1                 4              12310.0
# 2                 5             100000.0
# 3                 5              50970.0
# 4                 8             100000.0
# ...             ...                  ...
# 1209              8              16230.0
# 1210              4              57280.0
# 1211              3              27000.0
# 1212              4               2940.0
# 1213              5                640.0
#
# [1214 rows x 9 columns]

# %%
df_norm.standard_value_norm.describe()
# Out:
# count      1214.00000
# mean      47043.73229
# std       34753.18254
# min           6.00000
# 25%       20000.00000
# 50%       40485.00000
# 75%       69380.00000
# max      432000.00000
# Name: standard_value_norm, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1209      CHEMBL5205657  COc1ccc(C(=O)CN2C/C(=C/c3ccc([N+](=O)[O-])cc3)...
# 1210       CHEMBL379110  COc1cc(O)c(C(=O)[C@@H]2[C@H](CC=C(C)C)C(C)=CC[...
# 1211      CHEMBL1187898  CCN1/C(=C/C=C/c2oc3ccc4ccccc4c3[n+]2CC)Oc2ccc3...
# 1212      CHEMBL1458891    Cc1ccc(C2=NC(=O)/C(=C/c3cc(O)c(O)c(Br)c3)S2)cc1
# 1213         CHEMBL1324       Cc1ccc(C(=O)c2cc(O)c(O)c([N+](=O)[O-])c2)cc1
#
#      bioactivity_class bioactivity_class.1       MW     LogP  NumHDonors  \
# 0             inactive            inactive  240.262  2.80020           0
# 1             inactive            inactive  268.224  2.44040           1
# 2             inactive            inactive  407.426  1.38560           1
# 3             inactive            inactive  306.277  3.84800           1
# 4             inactive            inactive  372.772  2.36698           0
# ...                ...                 ...      ...      ...         ...
# 1209            active              active  513.506  4.74620           0
# 1210            active              active  406.522  6.01160           2
# 1211            active              active  433.531  6.82010           0
# 1212      intermediate        intermediate  390.258  4.22982           2
# 1213      intermediate        intermediate  273.244  2.54542           2
#
#       NumHAcceptors     pIC50
# 0                 4  4.000000
# 1                 4  4.909742
# 2                 5  4.000000
# 3                 5  4.292685
# 4                 8  4.000000
# ...             ...       ...
# 1209              8  4.789681
# 1210              4  4.241997
# 1211              3  4.568636
# 1212              4  5.531653
# 1213              5  6.193820
#
# [1214 rows x 9 columns]

# %%
df_final.pIC50.describe()
# Out:
# count    1214.000000
# mean        4.519783
# std         0.540001
# min         3.364516
# 25%         4.158766
# 50%         4.392706
# 75%         4.698970
# max         8.221849
# Name: pIC50, dtype: float64

# %%
df_final.to_csv('bioactivity_data_3class_pIC50.csv')

# %% [markdown]
# ### **Removing the Intermediate Bioacticity data**

# %%
df_2class = df_final[df_final.bioactivity_class != 'intermediate']
df_2class
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1207      CHEMBL4456898  CCCCC1C(C(=O)N(C)OC)C(c2ccccc2)CCN1C(=O)OC(C)(C)C
# 1208      CHEMBL5206054  O=C1/C(=C\c2ccc([N+](=O)[O-])cc2)CN(CC(=O)c2cc...
# 1209      CHEMBL5205657  COc1ccc(C(=O)CN2C/C(=C/c3ccc([N+](=O)[O-])cc3)...
# 1210       CHEMBL379110  COc1cc(O)c(C(=O)[C@@H]2[C@H](CC=C(C)C)C(C)=CC[...
# 1211      CHEMBL1187898  CCN1/C(=C/C=C/c2oc3ccc4ccccc4c3[n+]2CC)Oc2ccc3...
#
#      bioactivity_class bioactivity_class.1       MW     LogP  NumHDonors  \
# 0             inactive            inactive  240.262  2.80020           0
# 1             inactive            inactive  268.224  2.44040           1
# 2             inactive            inactive  407.426  1.38560           1
# 3             inactive            inactive  306.277  3.84800           1
# 4             inactive            inactive  372.772  2.36698           0
# ...                ...                 ...      ...      ...         ...
# 1207            active              active  404.551  4.60580           0
# 1208            active              active  501.470  4.87670           0
# 1209            active              active  513.506  4.74620           0
# 1210            active              active  406.522  6.01160           2
# 1211            active              active  433.531  6.82010           0
#
#       NumHAcceptors     pIC50
# 0                 4  4.000000
# 1                 4  4.909742
# 2                 5  4.000000
# 3                 5  4.292685
# 4                 8  4.000000
# ...             ...       ...
# 1207              4  3.589391
# 1208              7  4.817585
# 1209              8  4.789681
# 1210              4  4.241997
# 1211              3  4.568636
#
# [1078 rows x 9 columns]

# %%
df_2class.to_csv('bioactivity_data_2class_pIC50.csv')

# %%
print(df_2class.columns)
# Out:
# Index(['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class',
#        'bioactivity_class.1', 'MW', 'LogP', 'NumHDonors', 'NumHAcceptors',
#        'pIC50'],
#       dtype='object')

# %% [markdown]
# ## **Exploratory Data Analysis via Lipinski descriptors**

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %%
df_2class['bioactivity_class'].value_counts()
# Out:
# bioactivity_class
# inactive    1040
# active        38
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

colors = sns.color_palette("Set2", len(df_2class['bioactivity_class'].unique()))

plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='bioactivity_class', data=df_2class, edgecolor='black', palette=colors)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot_bioactivity_class.pdf')
# Out:
# <ipython-input-152-d23c0d874acc>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='bioactivity_class', data=df_2class, edgecolor='black', palette=colors)

# %% [markdown]
# ### **Scatter plot of MW versus LogP**
#
# It can be seen that the 2 bioactivity classes are spanning similar chemical spaces as evident by the scatter plot of MW vs LogP.

# %%
plt.figure(figsize=(5.5, 5.5))

sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='bioactivity_class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %% [markdown]
# ### **Box plots**

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
def mannwhitney(descriptor, verbose=False):
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu


  seed(1)

# actives and inactives
  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  active = df[df.bioactivity_class == 'active']
  active = active[descriptor]

  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  inactive = df[df.bioactivity_class == 'inactive']
  inactive = inactive[descriptor]

  stat, p = mannwhitneyu(active, inactive)


# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'

  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %% [markdown]
# #### **pIC50 value**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

colors = sns.color_palette("Set2", len(df_2class['bioactivity_class'].unique()))

plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x='bioactivity_class', y='pIC50', data=df_2class, palette=colors)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('plot_ic50.pdf')
# Out:
# <ipython-input-155-d5633908e35a>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='bioactivity_class', y='pIC50', data=df_2class, palette=colors)

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics             p  alpha  \
# 0      pIC50     32141.0  4.700999e-11   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **MW**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

colors = sns.color_palette("Set2", len(df_2class['bioactivity_class'].unique()))

plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x='bioactivity_class', y='MW', data=df_2class, palette=colors)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('plot_MW.pdf')
# Out:
# <ipython-input-158-531135bebc73>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='bioactivity_class', y='MW', data=df_2class, palette=colors)

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics             p  alpha  \
# 0         MW     30923.0  3.189840e-09   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **LogP**

# %%
plt.figure(figsize=(5.5, 5.5))

colors = sns.color_palette("Set2", len(df_2class['bioactivity_class'].unique()))

sns.boxplot(x = 'bioactivity_class', y = 'LogP', data = df_2class, palette = colors)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('plot_LogP.pdf')
# Out:
# <ipython-input-163-ead04f005b07>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'bioactivity_class', y = 'LogP', data = df_2class, palette = colors)

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics             p  alpha  \
# 0       LogP     29885.5  7.824001e-08   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **NumHDonors**

# %%
plt.figure(figsize=(5.5, 5.5))
colors = sns.color_palette("Set2", len(df_2class['bioactivity_class'].unique()))

sns.boxplot(x = 'bioactivity_class', y = 'NumHDonors', data = df_2class, palette=colors)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')
# Out:
# <ipython-input-165-fe727f5c8e75>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'bioactivity_class', y = 'NumHDonors', data = df_2class, palette=colors)

# %% [markdown]
# **Statistical analysis | Mann-Whitney U Test**

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics             p  alpha  \
# 0  NumHDonors     28839.5  6.498029e-07   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %% [markdown]
# #### **NumHAcceptors**

# %%
plt.figure(figsize=(5.5, 5.5))
colors = sns.color_palette("Set2", len(df_2class['bioactivity_class'].unique()))

sns.boxplot(x = 'bioactivity_class', y = 'NumHAcceptors', data = df_2class, palette=colors)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')
# Out:
# <ipython-input-172-f44e637dae60>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'bioactivity_class', y = 'NumHAcceptors', data = df_2class, palette=colors)

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics         p  alpha  \
# 0  NumHAcceptors     18165.0  0.390922   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# ## **Zip files**

# %%
! zip -r results.zip . -i *.csv *.pdf
# Out:
# 	zip warning: name not matched: miniconda/pkgs/python-3.7.6-h0371630_2/compiler_compat/ld
# 	zip warning: name not matched: drive/MyDrive/Classroom/Introduction to Human Computer Interaction Section B/Nihal IIITD - IHCI Tutorial 1.gdoc
# 	zip warning: name not matched: drive/MyDrive/Classroom/Introduction to Human Computer Interaction Section B/Nihal IIITD - Tutorial-4 Friday.gdoc
#   adding: plot_ic50.pdf (deflated 37%)
#   adding: bioactivity_data_2class_pIC50.csv (deflated 71%)
#   adding: mannwhitneyu_pIC50.csv (deflated 10%)
#   adding: bioactivity_preprocessed_data.csv (deflated 80%)
#   adding: mannwhitneyu_NumHAcceptors.csv (deflated 10%)
#   adding: mannwhitneyu_LogP.csv (deflated 9%)
#   adding: plot_NumHDonors.pdf (deflated 37%)
#   adding: plot_MW.pdf (deflated 37%)
#   adding: plot_MW_vs_LogP.pdf (deflated 3%)
#   adding: plot_LogP.pdf (deflated 38%)
#   adding: bioactivity_data_3class_pIC50.csv (deflated 72%)
#   adding: mannwhitneyu_MW.csv (deflated 8%)
#   adding: plot_NumHAcceptors.pdf (deflated 37%)
#   adding: mannwhitneyu_NumHDonors.csv (deflated 10%)
#   adding: plot_bioactivity_class.pdf (deflated 38%)
