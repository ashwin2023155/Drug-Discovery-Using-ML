# %% [markdown]
# <a href="https://colab.research.google.com/github/GolDRoger69/Drug-Discovery-using-ML/blob/main/Python/PB_project_bioactivity_Data_Set_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Installing libraries**

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.3 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %%
# Target search for Dengue
target = new_client.target
target_query = target.search('dengue')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references                                           organism  \
# 0               []                                       Dengue virus
# 1               []                                dengue virus type 4
# 2               []                                dengue virus type 1
# 3               []                                dengue virus type 2
# 4               []                                dengue virus type 3
# 5               []  Dengue virus type 2 (strain Thailand/16681/198...
#
#                          pref_name  score  species_group_flag  \
# 0                     Dengue virus   14.0               False
# 1              dengue virus type 4   11.0               False
# 2              dengue virus type 1   11.0               False
# 3              dengue virus type 2   11.0               False
# 4              dengue virus type 3   11.0               False
# 5  Dengue virus type 2 NS3 protein    9.0               False
#
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for Dengue virus type 2 NS3 protein	(sixth entry)**

# %%
selected_target = targets.target_chembl_id[5]
selected_target
# Out:
# 'CHEMBL5980'

# %% [markdown]
# Here, we will retrieve only bioactivity data for Dengue virus type 2 NS3 protein (CHEMBL5980) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None           active      7018430                  []
# 1        None           active      7018431                  []
# 2        None           active      7018432                  []
# 3        None           active      7018433                  []
# 4        None           active      7018434                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1794550  PUBCHEM_BIOASSAY: Primary and Confirmatory Scr...
# 1   CHEMBL1794550  PUBCHEM_BIOASSAY: Primary and Confirmatory Scr...
# 2   CHEMBL1794550  PUBCHEM_BIOASSAY: Primary and Confirmatory Scr...
# 3   CHEMBL1794550  PUBCHEM_BIOASSAY: Primary and Confirmatory Scr...
# 4   CHEMBL1794550  PUBCHEM_BIOASSAY: Primary and Confirmatory Scr...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000190  ...
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 831
# -rw------- 1 root root 850407 May  3 09:19 bioactivity_data.csv

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None           active
# 1                                                  None           active
# 2                                                  None           active
# 3                                                  None           active
# 4                                                  None           active
# ...                                                 ...              ...
# 1314  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1315  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1316  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1317  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1318  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be active while those greater than 10,000 nM will be considered to be inactive. As for those values in between 1,000 and 10,000 nM will be referred to as intermediate.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]

df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1314      CHEMBL5421390  CN([C@@H](Cc1ccc(C(=N)N)cc1)C(=O)N[C@@H](CCCCN...
# 1315      CHEMBL5421971  CN([C@@H](Cc1ccc(C(=N)N)cc1)C(=O)N[C@@H](CCCCN...
# 1316      CHEMBL5413511  CN([C@@H](Cc1ccc(C(=N)N)cc1)C(=O)N[C@@H](CCCCN...
# 1317          CHEMBL164      O=c1c(O)c(-c2cc(O)c(O)c(O)c2)oc2cc(O)cc(O)c12
# 1318      CHEMBL3819036            O=C(CCCCCCCCc1ccc(O)cc1)c1c(O)cc(O)cc1O
#
#      standard_value
# 0          100000.0
# 1           12310.0
# ...

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df3 = pd.concat([df3, bioactivity_class], axis=1)
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1195                NaN                                                NaN
# 1197                NaN                                                NaN
# 1199                NaN                                                NaN
# 1201                NaN                                                NaN
# 1206                NaN                                                NaN
#
#      standard_value bioactivity_class bioactivity_class
# ...

# %% [markdown]
# ### ***Saving Data frame to CSV file***

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 960
# -rw-r--r-- 1 root root 850407 May  3 09:15 bioactivity_data.csv
# -rw-r--r-- 1 root root 122117 May  3 09:37 bioactivity_preprocessed_data.csv
# drwx------ 6 root root   4096 May  3 09:17 gdrive
# drwxr-xr-x 1 root root   4096 Apr 30 13:37 sample_data

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv
