# %% [markdown]
# <a href="https://colab.research.google.com/github/GolDRoger69/Drug-Discovery-using-ML/blob/main/Python/PB_project_regressors_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1. Libraries**

# %%
# !pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.11/dist-packages (0.2.16)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from lazypredict) (8.1.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from lazypredict) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lazypredict) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (from lazypredict) (4.5.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (from lazypredict) (2.1.4)
# Requirement already satisfied: pytest-runner in /usr/local/lib/python3.11/dist-packages (from lazypredict) (6.0.1)
# Requirement already satisfied: mlflow>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from lazypredict) (2.22.0)
# Requirement already satisfied: mlflow-skinny==2.22.0 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (2.22.0)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (3.1.6)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (1.15.2)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (7.1.0)
# Requirement already satisfied: graphene<4 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (23.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (3.8)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (2.0.2)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (18.1.0)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (1.15.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow>=2.0.0->lazypredict) (2.0.40)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (5.5.2)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (0.52.0)
# Requirement already satisfied: fastapi<1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (0.115.12)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (1.16.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (1.16.0)
# Requirement already satisfied: packaging<25 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (5.29.4)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (2.11.4)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (4.13.2)
# Requirement already satisfied: uvicorn<1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (0.34.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->lazypredict) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->lazypredict) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->lazypredict) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost->lazypredict) (2.21.5)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazypredict) (1.1.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->lazypredict) (2.4.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (1.9.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /usr/local/lib/python3.11/dist-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /usr/local/lib/python3.11/dist-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2<4,>=2.11->mlflow>=2.0.0->lazypredict) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.0.0->lazypredict) (3.2.1)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.11/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (2.38.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi<1->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (0.46.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (1.2.18)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (75.2.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.37b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (0.37b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (2025.4.26)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<1->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=2.0.0->lazypredict) (0.6.1)

# %% [markdown]
# ## **2. Mounting Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

BASE = '/content/drive/MyDrive/Colab Notebooks/data/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **2.1 Loading Essential Files**

# %%
import pickle, pandas as pd

# Evaluation metrics & test predictions (optional)
with open(BASE + 'evaluation_results_tuned.pkl','rb') as f:
    eval_res = pickle.load(f)
print("Saved Eval Metrics:", eval_res)

with open(BASE + 'predictions_data_tuned.pkl','rb') as f:
    preds = pickle.load(f)
pred_df = pd.DataFrame(preds)
print("\nSaved Test Predictions:\n", pred_df.head())

# Preprocessing objects & trained model
with open(BASE + 'scaler.pkl','rb')   as f: scaler   = pickle.load(f)
with open(BASE + 'selector.pkl','rb') as f: selector = pickle.load(f)
with open(BASE + 'best_random_forest_model.pkl','rb') as f:
    best_model = pickle.load(f)
print("\nLoaded model, scaler, selector.")
# Out:
# Saved Eval Metrics: {'Best Parameters': {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}, 'R² score': 0.37395919939185374, 'MSE': 0.15329552279578262}
#
# Saved Test Predictions:
#         Actual  Predicted
# 739  4.511026   4.317927
# 788  4.000000   4.379512
# 43   4.633204   4.496216
# 155  4.365624   4.362989
# 494  4.674484   4.350870
#
# Loaded model, scaler, selector.

# %% [markdown]
# ## **2.2 Train/Test Split of Data**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
# 2. Load and preprocess your data (same CSV you trained on)
df = pd.read_csv(BASE + 'bioactivity_data_3class_pIC50_pubchem_fp.csv')
df.fillna(df.mean(), inplace=True)

X = df.drop(columns=['pIC50'])
y = df['pIC50']

# 3. Apply scaling and variance threshold
X_scaled   = scaler.transform(X)
X_selected = selector.transform(X_scaled)

# 4. Train/test split (same seed)
X_train, X_test, Y_train, Y_test = train_test_split(
    X_selected, y, test_size=0.2, random_state=42
)

print(f"Data shapes → X_train: {X_train.shape}, X_test: {X_test.shape}")
# Out:
# Data shapes → X_train: (971, 601), X_test: (243, 601)

# %% [markdown]
# ## **3. LazyPredict**

# %%
# 5. Run LazyRegressor
clf = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)

# 5a. Benchmark on train split
models_train, preds_train = clf.fit(X_train, X_train, Y_train, Y_train)

# 5b. Benchmark on test split
models_test, preds_test   = clf.fit(X_train, X_test,  Y_train, Y_test)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004724 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1335
# [LightGBM] [Info] Number of data points in the train set: 971, number of used features: 445
# [LightGBM] [Info] Start training from score 4.524325
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004647 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1335
# [LightGBM] [Info] Number of data points in the train set: 971, number of used features: 445
# [LightGBM] [Info] Start training from score 4.524325

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# 6. Compute your tuned RF’s metrics on the same test set
y_pred_rf = best_model.predict(X_test)
r2_rf     = r2_score(Y_test, y_pred_rf)
rmse_rf   = np.sqrt(mean_squared_error(Y_test, y_pred_rf))

print(f"Tuned RF → TEST R²: {r2_rf:.4f}, RMSE: {rmse_rf:.4f}")

# 7. Merge your RF into the LazyRegressor table
df_models = models_test.reset_index().rename(columns={'index':'Model'})
my_row = pd.DataFrame([{
    'Model'     : 'Tuned RandomForest',
    'R-Squared' : r2_rf,
    'RMSE'      : rmse_rf,
    'Time Taken': np.nan
}], columns=df_models.columns)

comparison = pd.concat([df_models, my_row], ignore_index=True)
# Out:
# Tuned RF → TEST R²: 0.3740, RMSE: 0.3915

# %%
# 7. Merge your RF into the LazyRegressor table
df_models = models_test.reset_index().rename(columns={'index':'Model'})
my_row = pd.DataFrame([{
    'Model'     : 'Tuned RandomForest',
    'R-Squared' : r2_rf,
    'RMSE'      : rmse_rf,
    'Time Taken': np.nan
}], columns=df_models.columns)

# comparison = pd.concat([df_models, my_row], ignore_index=True)

# # 8. Print full comparison
# pd.set_option('display.max_rows', None)
# print("\n=== LazyRegressor vs. Tuned RF on Test Split ===")
# print(comparison)
lazy_vs_tuned = pd.concat([df_models, my_row], ignore_index=True)

# %%
preds_test
# Out:
#                                               Adjusted R-Squared  \
# Model
# Lars                          1574399534794129759088410624000.00
# SGDRegressor                                74422543957058912.00
# KernelRidge                                                58.92
# GaussianProcessRegressor                                   50.43
# RANSACRegressor                                            11.72
# MLPRegressor                                                2.90
# TransformedTargetRegressor                                  2.33
# LinearRegression                                            2.33
# LinearSVR                                                   2.26
# PassiveAggressiveRegressor                                  1.93
# Ridge                                                       1.86
# ExtraTreeRegressor                                          1.80
# DecisionTreeRegressor                                       1.79
# HuberRegressor                                              1.76
# QuantileRegressor                                           1.70
# ExtraTreesRegressor                                         1.69
# DummyRegressor                                              1.68
# ElasticNet                                                  1.68
# LassoLars                                                   1.68
# Lasso                                                       1.68
# RidgeCV                                                     1.67
# AdaBoostRegressor                                           1.57
# OrthogonalMatchingPursuitCV                                 1.53
# OrthogonalMatchingPursuit                                   1.52
# PoissonRegressor                                            1.51
# BayesianRidge                                               1.50
# TweedieRegressor                                            1.49
# KNeighborsRegressor                                         1.49
# GammaRegressor                                              1.49
# ElasticNetCV                                                1.48
# LassoCV                                                     1.48
# BaggingRegressor                                            1.48
# XGBRegressor                                                1.46
# HistGradientBoostingRegressor                               1.46
# LassoLarsIC                                                 1.46
# LassoLarsCV                                                 1.46
# LarsCV                                                      1.45
# SVR                                                         1.45
# NuSVR                                                       1.45
# GradientBoostingRegressor                                   1.45
# LGBMRegressor                                               1.44
# RandomForestRegressor                                       1.43
#
#                                                         R-Squared  \
# Model
# Lars                          -2335576169384679894777245728768.00
# SGDRegressor                               -110403691242083264.00
# KernelRidge                                                -84.93
# GaussianProcessRegressor                                   -72.32
# RANSACRegressor                                            -14.90
# MLPRegressor                                                -1.82
# TransformedTargetRegressor                                  -0.98
# LinearRegression                                            -0.98
# LinearSVR                                                   -0.87
# PassiveAggressiveRegressor                                  -0.39
# Ridge                                                       -0.28
# ExtraTreeRegressor                                          -0.19
# DecisionTreeRegressor                                       -0.17
# HuberRegressor                                              -0.13
# QuantileRegressor                                           -0.05
# ExtraTreesRegressor                                         -0.03
# DummyRegressor                                              -0.00
# ElasticNet                                                  -0.00
# LassoLars                                                   -0.00
# Lasso                                                       -0.00
# RidgeCV                                                      0.01
# AdaBoostRegressor                                            0.16
# OrthogonalMatchingPursuitCV                                  0.22
# OrthogonalMatchingPursuit                                    0.22
# PoissonRegressor                                             0.24
# BayesianRidge                                                0.26
# TweedieRegressor                                             0.27
# KNeighborsRegressor                                          0.27
# GammaRegressor                                               0.28
# ElasticNetCV                                                 0.28
# LassoCV                                                      0.28
# BaggingRegressor                                             0.29
# XGBRegressor                                                 0.31
# HistGradientBoostingRegressor                                0.32
# LassoLarsIC                                                  0.32
# LassoLarsCV                                                  0.32
# LarsCV                                                       0.33
# SVR                                                          0.33
# NuSVR                                                        0.33
# GradientBoostingRegressor                                    0.34
# LGBMRegressor                                                0.35
# RandomForestRegressor                                        0.37
#
#                                             RMSE  Time Taken
# Model
# Lars                          756241374155062.00        0.53
# SGDRegressor                        164420215.58        0.08
# KernelRidge                                 4.59        0.16
# GaussianProcessRegressor                    4.24        2.32
# RANSACRegressor                             1.97       20.76
# MLPRegressor                                0.83        4.18
# TransformedTargetRegressor                  0.70        0.22
# LinearRegression                            0.70        0.46
# LinearSVR                                   0.68        2.41
# PassiveAggressiveRegressor                  0.58        0.13
# Ridge                                       0.56        0.20
# ExtraTreeRegressor                          0.54        0.16
# DecisionTreeRegressor                       0.53        0.17
# HuberRegressor                              0.52        1.55
# QuantileRegressor                           0.51       13.33
# ExtraTreesRegressor                         0.50        8.33
# DummyRegressor                              0.50        0.05
# ElasticNet                                  0.50        0.08
# LassoLars                                   0.50        0.12
# Lasso                                       0.50        0.08
# RidgeCV                                     0.49        0.48
# AdaBoostRegressor                           0.45        0.61
# OrthogonalMatchingPursuitCV                 0.44        0.24
# OrthogonalMatchingPursuit                   0.44        0.08
# PoissonRegressor                            0.43        0.76
# BayesianRidge                               0.43        0.54
# TweedieRegressor                            0.42        0.30
# KNeighborsRegressor                         0.42        0.10
# GammaRegressor                              0.42        0.27
# ElasticNetCV                                0.42       35.20
# LassoCV                                     0.42       30.83
# BaggingRegressor                            0.42        0.70
# XGBRegressor                                0.41        0.40
# HistGradientBoostingRegressor               0.41        3.56
# LassoLarsIC                                 0.41        0.43
# LassoLarsCV                                 0.41        0.31
# LarsCV                                      0.41        2.10
# SVR                                         0.41        0.36
# NuSVR                                       0.41        0.47
# GradientBoostingRegressor                   0.40        2.41
# LGBMRegressor                               0.40        0.30
# RandomForestRegressor                       0.39        7.56

# %%
lazy_vs_tuned
# Out:
#                             Model                 Adjusted R-Squared  \
# 0                            Lars 1574399534794129759088410624000.00
# 1                    SGDRegressor               74422543957058912.00
# 2                     KernelRidge                              58.92
# 3        GaussianProcessRegressor                              50.43
# 4                 RANSACRegressor                              11.72
# 5                    MLPRegressor                               2.90
# 6      TransformedTargetRegressor                               2.33
# 7                LinearRegression                               2.33
# 8                       LinearSVR                               2.26
# 9      PassiveAggressiveRegressor                               1.93
# 10                          Ridge                               1.86
# 11             ExtraTreeRegressor                               1.80
# 12          DecisionTreeRegressor                               1.79
# 13                 HuberRegressor                               1.76
# 14              QuantileRegressor                               1.70
# 15            ExtraTreesRegressor                               1.69
# 16                 DummyRegressor                               1.68
# 17                     ElasticNet                               1.68
# 18                      LassoLars                               1.68
# 19                          Lasso                               1.68
# 20                        RidgeCV                               1.67
# 21              AdaBoostRegressor                               1.57
# 22    OrthogonalMatchingPursuitCV                               1.53
# 23      OrthogonalMatchingPursuit                               1.52
# 24               PoissonRegressor                               1.51
# 25                  BayesianRidge                               1.50
# 26               TweedieRegressor                               1.49
# 27            KNeighborsRegressor                               1.49
# 28                 GammaRegressor                               1.49
# 29                   ElasticNetCV                               1.48
# 30                        LassoCV                               1.48
# 31               BaggingRegressor                               1.48
# 32                   XGBRegressor                               1.46
# 33  HistGradientBoostingRegressor                               1.46
# 34                    LassoLarsIC                               1.46
# 35                    LassoLarsCV                               1.46
# 36                         LarsCV                               1.45
# 37                            SVR                               1.45
# 38                          NuSVR                               1.45
# 39      GradientBoostingRegressor                               1.45
# 40                  LGBMRegressor                               1.44
# 41          RandomForestRegressor                               1.43
# 42             Tuned RandomForest                                NaN
#
#                              R-Squared               RMSE  Time Taken
# 0  -2335576169384679894777245728768.00 756241374155062.00        0.53
# 1               -110403691242083264.00       164420215.58        0.08
# 2                               -84.93               4.59        0.16
# 3                               -72.32               4.24        2.32
# 4                               -14.90               1.97       20.76
# 5                                -1.82               0.83        4.18
# 6                                -0.98               0.70        0.22
# 7                                -0.98               0.70        0.46
# 8                                -0.87               0.68        2.41
# 9                                -0.39               0.58        0.13
# 10                               -0.28               0.56        0.20
# 11                               -0.19               0.54        0.16
# 12                               -0.17               0.53        0.17
# 13                               -0.13               0.52        1.55
# 14                               -0.05               0.51       13.33
# 15                               -0.03               0.50        8.33
# 16                               -0.00               0.50        0.05
# 17                               -0.00               0.50        0.08
# 18                               -0.00               0.50        0.12
# 19                               -0.00               0.50        0.08
# 20                                0.01               0.49        0.48
# 21                                0.16               0.45        0.61
# 22                                0.22               0.44        0.24
# 23                                0.22               0.44        0.08
# 24                                0.24               0.43        0.76
# 25                                0.26               0.43        0.54
# 26                                0.27               0.42        0.30
# 27                                0.27               0.42        0.10
# 28                                0.28               0.42        0.27
# 29                                0.28               0.42       35.20
# 30                                0.28               0.42       30.83
# 31                                0.29               0.42        0.70
# 32                                0.31               0.41        0.40
# 33                                0.32               0.41        3.56
# 34                                0.32               0.41        0.43
# 35                                0.32               0.41        0.31
# 36                                0.33               0.41        2.10
# 37                                0.33               0.41        0.36
# 38                                0.33               0.41        0.47
# 39                                0.34               0.40        2.41
# 40                                0.35               0.40        0.30
# 41                                0.37               0.39        7.56
# 42                                0.37               0.39         NaN

# %%
models_test
# Out:
#                                               Adjusted R-Squared  \
# Model
# Lars                          1574399534794129759088410624000.00
# SGDRegressor                                74422543957058912.00
# KernelRidge                                                58.92
# GaussianProcessRegressor                                   50.43
# RANSACRegressor                                            11.72
# MLPRegressor                                                2.90
# TransformedTargetRegressor                                  2.33
# LinearRegression                                            2.33
# LinearSVR                                                   2.26
# PassiveAggressiveRegressor                                  1.93
# Ridge                                                       1.86
# ExtraTreeRegressor                                          1.80
# DecisionTreeRegressor                                       1.79
# HuberRegressor                                              1.76
# QuantileRegressor                                           1.70
# ExtraTreesRegressor                                         1.69
# DummyRegressor                                              1.68
# ElasticNet                                                  1.68
# LassoLars                                                   1.68
# Lasso                                                       1.68
# RidgeCV                                                     1.67
# AdaBoostRegressor                                           1.57
# OrthogonalMatchingPursuitCV                                 1.53
# OrthogonalMatchingPursuit                                   1.52
# PoissonRegressor                                            1.51
# BayesianRidge                                               1.50
# TweedieRegressor                                            1.49
# KNeighborsRegressor                                         1.49
# GammaRegressor                                              1.49
# ElasticNetCV                                                1.48
# LassoCV                                                     1.48
# BaggingRegressor                                            1.48
# XGBRegressor                                                1.46
# HistGradientBoostingRegressor                               1.46
# LassoLarsIC                                                 1.46
# LassoLarsCV                                                 1.46
# LarsCV                                                      1.45
# SVR                                                         1.45
# NuSVR                                                       1.45
# GradientBoostingRegressor                                   1.45
# LGBMRegressor                                               1.44
# RandomForestRegressor                                       1.43
#
#                                                         R-Squared  \
# Model
# Lars                          -2335576169384679894777245728768.00
# SGDRegressor                               -110403691242083264.00
# KernelRidge                                                -84.93
# GaussianProcessRegressor                                   -72.32
# RANSACRegressor                                            -14.90
# MLPRegressor                                                -1.82
# TransformedTargetRegressor                                  -0.98
# LinearRegression                                            -0.98
# LinearSVR                                                   -0.87
# PassiveAggressiveRegressor                                  -0.39
# Ridge                                                       -0.28
# ExtraTreeRegressor                                          -0.19
# DecisionTreeRegressor                                       -0.17
# HuberRegressor                                              -0.13
# QuantileRegressor                                           -0.05
# ExtraTreesRegressor                                         -0.03
# DummyRegressor                                              -0.00
# ElasticNet                                                  -0.00
# LassoLars                                                   -0.00
# Lasso                                                       -0.00
# RidgeCV                                                      0.01
# AdaBoostRegressor                                            0.16
# OrthogonalMatchingPursuitCV                                  0.22
# OrthogonalMatchingPursuit                                    0.22
# PoissonRegressor                                             0.24
# BayesianRidge                                                0.26
# TweedieRegressor                                             0.27
# KNeighborsRegressor                                          0.27
# GammaRegressor                                               0.28
# ElasticNetCV                                                 0.28
# LassoCV                                                      0.28
# BaggingRegressor                                             0.29
# XGBRegressor                                                 0.31
# HistGradientBoostingRegressor                                0.32
# LassoLarsIC                                                  0.32
# LassoLarsCV                                                  0.32
# LarsCV                                                       0.33
# SVR                                                          0.33
# NuSVR                                                        0.33
# GradientBoostingRegressor                                    0.34
# LGBMRegressor                                                0.35
# RandomForestRegressor                                        0.37
#
#                                             RMSE  Time Taken
# Model
# Lars                          756241374155062.00        0.53
# SGDRegressor                        164420215.58        0.08
# KernelRidge                                 4.59        0.16
# GaussianProcessRegressor                    4.24        2.32
# RANSACRegressor                             1.97       20.76
# MLPRegressor                                0.83        4.18
# TransformedTargetRegressor                  0.70        0.22
# LinearRegression                            0.70        0.46
# LinearSVR                                   0.68        2.41
# PassiveAggressiveRegressor                  0.58        0.13
# Ridge                                       0.56        0.20
# ExtraTreeRegressor                          0.54        0.16
# DecisionTreeRegressor                       0.53        0.17
# HuberRegressor                              0.52        1.55
# QuantileRegressor                           0.51       13.33
# ExtraTreesRegressor                         0.50        8.33
# DummyRegressor                              0.50        0.05
# ElasticNet                                  0.50        0.08
# LassoLars                                   0.50        0.12
# Lasso                                       0.50        0.08
# RidgeCV                                     0.49        0.48
# AdaBoostRegressor                           0.45        0.61
# OrthogonalMatchingPursuitCV                 0.44        0.24
# OrthogonalMatchingPursuit                   0.44        0.08
# PoissonRegressor                            0.43        0.76
# BayesianRidge                               0.43        0.54
# TweedieRegressor                            0.42        0.30
# KNeighborsRegressor                         0.42        0.10
# GammaRegressor                              0.42        0.27
# ElasticNetCV                                0.42       35.20
# LassoCV                                     0.42       30.83
# BaggingRegressor                            0.42        0.70
# XGBRegressor                                0.41        0.40
# HistGradientBoostingRegressor               0.41        3.56
# LassoLarsIC                                 0.41        0.43
# LassoLarsCV                                 0.41        0.31
# LarsCV                                      0.41        2.10
# SVR                                         0.41        0.36
# NuSVR                                       0.41        0.47
# GradientBoostingRegressor                   0.40        2.41
# LGBMRegressor                               0.40        0.30
# RandomForestRegressor                       0.39        7.56

# %%
models_train
# Out:
#                                   Adjusted R-Squared              R-Squared  \
# Model
# ExtraTreeRegressor                              0.89                   0.96
# DecisionTreeRegressor                           0.89                   0.96
# ExtraTreesRegressor                             0.89                   0.96
# GaussianProcessRegressor                        0.89                   0.96
# XGBRegressor                                    0.85                   0.94
# MLPRegressor                                    0.84                   0.94
# RandomForestRegressor                           0.69                   0.88
# BaggingRegressor                                0.59                   0.85
# LGBMRegressor                                   0.55                   0.83
# HistGradientBoostingRegressor                   0.54                   0.83
# NuSVR                                           0.40                   0.77
# SVR                                             0.39                   0.77
# TransformedTargetRegressor                      0.31                   0.74
# LinearRegression                                0.31                   0.74
# Ridge                                           0.29                   0.73
# RidgeCV                                         0.22                   0.70
# GradientBoostingRegressor                       0.17                   0.68
# HuberRegressor                                  0.10                   0.66
# PoissonRegressor                                0.02                   0.63
# KNeighborsRegressor                            -0.08                   0.59
# LinearSVR                                      -0.11                   0.58
# BayesianRidge                                  -0.15                   0.56
# ElasticNetCV                                   -0.16                   0.56
# LassoCV                                        -0.18                   0.55
# OrthogonalMatchingPursuit                      -0.20                   0.54
# TweedieRegressor                               -0.25                   0.52
# GammaRegressor                                 -0.26                   0.52
# OrthogonalMatchingPursuitCV                    -0.36                   0.48
# AdaBoostRegressor                              -0.40                   0.47
# PassiveAggressiveRegressor                     -0.43                   0.46
# LarsCV                                         -0.47                   0.44
# LassoLarsCV                                    -0.50                   0.43
# LassoLarsIC                                    -0.50                   0.43
# ElasticNet                                     -1.63                   0.00
# DummyRegressor                                 -1.63                   0.00
# LassoLars                                      -1.63                   0.00
# Lasso                                          -1.63                   0.00
# QuantileRegressor                              -1.77                  -0.05
# RANSACRegressor                               -10.17                  -3.25
# Lars                                         -159.00                 -59.87
# KernelRidge                                  -177.36                 -66.85
# SGDRegressor                  -352261993507924352.00 -134004820210746480.00
#
#                                       RMSE  Time Taken
# Model
# ExtraTreeRegressor                    0.11        0.19
# DecisionTreeRegressor                 0.11        0.27
# ExtraTreesRegressor                   0.11       12.89
# GaussianProcessRegressor              0.11        3.17
# XGBRegressor                          0.13        0.47
# MLPRegressor                          0.14        6.92
# RandomForestRegressor                 0.19        7.24
# BaggingRegressor                      0.22        0.92
# LGBMRegressor                         0.23        0.34
# HistGradientBoostingRegressor         0.23        4.08
# NuSVR                                 0.26        0.80
# SVR                                   0.26        0.72
# TransformedTargetRegressor            0.28        0.25
# LinearRegression                      0.28        0.26
# Ridge                                 0.29        0.21
# RidgeCV                               0.30        0.42
# GradientBoostingRegressor             0.31        1.49
# HuberRegressor                        0.32        1.63
# PoissonRegressor                      0.34        0.63
# KNeighborsRegressor                   0.35        0.16
# LinearSVR                             0.36        1.85
# BayesianRidge                         0.36        2.34
# ElasticNetCV                          0.37       37.03
# LassoCV                               0.37       30.87
# OrthogonalMatchingPursuit             0.37        0.09
# TweedieRegressor                      0.38        0.46
# GammaRegressor                        0.38        0.32
# OrthogonalMatchingPursuitCV           0.40        0.23
# AdaBoostRegressor                     0.40        0.68
# PassiveAggressiveRegressor            0.41        0.16
# LarsCV                                0.41        2.04
# LassoLarsCV                           0.42        0.38
# LassoLarsIC                           0.42        0.35
# ElasticNet                            0.55        0.14
# DummyRegressor                        0.55        0.08
# LassoLars                             0.55        0.12
# Lasso                                 0.55        0.08
# QuantileRegressor                     0.57       13.42
# RANSACRegressor                       1.13       27.29
# Lars                                  4.29        0.45
# KernelRidge                           4.53        0.33
# SGDRegressor                  201467622.38        0.11

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Generate a rainbow-style palette (using cubehelix with custom hue start)
rainbow_palette = sns.color_palette("hsv", len(lazy_vs_tuned))  # hsv gives vivid rainbow colors

# %%
plt.figure(figsize=(6, 12))
sns.set(style="whitegrid")

ax = sns.barplot(data=lazy_vs_tuned, y="Model", x="R-Squared", palette=rainbow)

# Reduce bar height and highlight the tuned model
for i, bar in enumerate(ax.patches):
    bar.set_height(0.6)
    model_name = lazy_vs_tuned.iloc[i]["Model"]
    if model_name == "Tuned RandomForest":
        bar.set_linewidth(2)
        # bar.set_edgecolor("red")
    else:
        bar.set_linewidth(0)

plt.title("Model Comparison: R-Squared", fontsize=14)
plt.xlim(0, 0.4)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 12))
sns.set(style="whitegrid")

ax = sns.barplot(data=lazy_vs_tuned, y="Model", x="RMSE", palette=rainbow_palette)

for i, bar in enumerate(ax.patches):
    bar.set_height(0.4)
    model_name = lazy_vs_tuned.iloc[i]["Model"]
    if model_name == "Tuned RandomForest":
        bar.set_linewidth(2)
        # bar.set_edgecolor("red")
    else:
        bar.set_linewidth(0)

plt.title("Model Comparison: RMSE", fontsize=14)
plt.xlim(0, 5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 12))
sns.set(style="whitegrid")
ax = sns.barplot(
    data=lazy_vs_tuned.sort_values("Time Taken", na_position='last'),
    y="Model", x="Time Taken", palette=rainbow_palette
)
ax.set_title("Model Comparison: Time Taken (s)", fontsize=14, fontweight='bold')
plt.xlim(0, 15)
plt.tight_layout()
plt.show()
